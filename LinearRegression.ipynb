# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv('placement.csv')
dataset.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
plt.Figure(figsize=(5,3))
sns.scatterplot(x="cgpa",y="package",data=dataset)
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
x=dataset[['cgpa']]
y=dataset[['package']]
x.ndim
# Out:
# 2

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[0.57425647]])

# %%
lr.intercept_
# Out:
# array([-1.02700694])

# %%
# y=0.57425647*x-1.02700694

# %%
lr.score(x_test,y_test)*100
# Out:
# 77.30984312051673

# %%
lr.predict([[6.89]])
# Out:
# c:\Users\dps23\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_prd=lr.predict(x)

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(x="cgpa", y="package", data=dataset)
plt.plot(dataset["cgpa"], y_prd, c="red", label="predict")
plt.legend(["org", "predict line"])
plt.savefig("predict.jpg")
plt.show()

# %%
y=0.57425647*6.89-1.02700694
y
# Out:
# 2.9296201383
