# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv('Loans.csv')

# %%
data.isnull().sum()
# Out:
# customer_id                3
# customer_age               0
# customer_income            0
# home_ownership             0
# employment_duration      895
# loan_intent                0
# loan_grade                 0
# loan_amnt                  1
# loan_int_rate           3116
# term_years                 0
# historical_default     20737
# cred_hist_length           0
# Current_loan_status        4
# dtype: int64

# %%
data.select_dtypes(include="float64").columns
# Out:
# Index(['customer_id', 'employment_duration', 'loan_int_rate'], dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy="mean")
ar =si.fit_transform(data[['customer_id', 'employment_duration', 'loan_int_rate']])

# %%
new_data=pd.DataFrame(ar,columns=data.select_dtypes(include="float64").columns)

# %%
new_data.isnull().sum()
# Out:
# customer_id            0
# employment_duration    0
# loan_int_rate          0
# dtype: int64

# %%
new_data
# Out:
#        customer_id  employment_duration  loan_int_rate
# 0              1.0                123.0          16.02
# 1              2.0                  5.0          11.14
# 2              3.0                  1.0          12.87
# 3              4.0                  4.0          15.23
# 4              5.0                  8.0          14.27
# ...            ...                  ...            ...
# 32581      32577.0                  1.0          13.16
# 32582      32578.0                  4.0           7.49
# 32583      32579.0                  3.0          10.99
# 32584      32580.0                  5.0          11.48
# 32585      32581.0                  2.0           9.99
#
# [32586 rows x 3 columns]

# %%
new_data['loan_int_rate'].mean()
# Out:
# np.float64(11.01155276552426)
